# %% [markdown]
# #H2
# ##H3
# ###H4
# ####H5
# #####H6
# ######H7

# %% [markdown]
# #heading tags

# %% [markdown]
# **This is Bold Tag**

# %% [markdown]
# *This is italic*

# %% [markdown]
# ***This is all bold and all italic***

# %% [markdown]
# ***This is example for All bold and nested Italic***

# %%
print("hello")
# Out:
# hello

# %%
n=int(input("Enter n:"))
f=1
for i in range(1,n+1):
  f=f*i
print("factorial of {} is {}".format(n,f))
# Out:
# Enter n:5
# factorial of 5 is 120

# %% [markdown]
# ~~~Strikethrough~~~
#
# 1. first-1
#
#   1.1.first-1.1
#
#       1.1.1.first-1.1.1N

# %% [markdown]
# please click [here](https://google.com)
